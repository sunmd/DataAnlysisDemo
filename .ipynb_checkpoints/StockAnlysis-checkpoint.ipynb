# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib as mpl
# mpl.rcParams['font.sans-serif'] = ['SimHei']
# mpl.rcParams['font.serif'] = ['SimHei']
# mpl.rcParams['axes.unicode_minus']=False
# mpl.rcParams['font.sans-serif'] = ['Helvetica']
import matplotlib.style as psl
print(plt.style.available)
# 查看样式列表
psl.use('ggplot')

% matplotlib inline
# Out:
# ['seaborn-dark', 'seaborn-muted', 'Solarize_Light2', 'seaborn-deep', 'dark_background', 'fast', 'seaborn-whitegrid', 'seaborn-colorblind', 'classic', 'tableau-colorblind10', 'seaborn-paper', 'grayscale', 'seaborn', 'seaborn-notebook', 'seaborn-pastel', 'seaborn-dark-palette', 'seaborn-ticks', 'seaborn-darkgrid', 'seaborn-white', 'seaborn-talk', 'fivethirtyeight', 'ggplot', 'seaborn-bright', 'bmh', '_classic_test', 'seaborn-poster']

# %%
#读取数据xls的数据,其实为csv的文件
def loadCsv(file,date_time):
    dataf = pd.read_csv(file, encoding='GB18030', delimiter='\t', header=1).drop('Unnamed: 8', axis=1)
    dataf['savetime'] = pd.to_datetime(date_time).strftime('%Y-%m-%d')
    return dataf

#读取数据xls的数据，真实xls
def loadExl(file,date_time):
    dataf = pd.read_excel(file, encoding='utf8', header=1)
    dataf['savetime'] = pd.to_datetime(date_time).strftime('%Y-%m-%d')
    return dataf

#列名重新定义
def reName(df, n):
    df.columns = n
    return df

#文件合成工厂(软件导出数据)
def loadExcFac(path,date_time,columnsName,nums):
    name1 = 'Table'
    name2 = '.xls'
    shuju = pd.DataFrame(columns=columnsName)
    for i in nums:
        name = path + name1 + str(i) + name2
        dateTime = date_time + '-' + str(i)
        df = loadCsv(name, dateTime)
        df = reName(df, columnsName)
        df['涨幅%'] = df['涨幅%'].str.strip("%").astype(float)/100
        shuju = shuju.append(df, ignore_index=True)
    return shuju

#文件合成工厂(手动调整的xls)
def loadExc2Fac(path,date_time,columnsName,nums):
    name1 = 'Table'
    name2 = '.xls'
    shuju = pd.DataFrame(columns=columnsName)
    for i in nums:
        name = path + name1 + str(i) + name2
        dateTime = date_time + '-' + str(i)
        df = loadExl(name, dateTime)
        df = reName(df, columnsName)
        df['涨幅%'] = df['涨幅%']
        shuju = shuju.append(df, ignore_index=True)
    return shuju

#合并数据
def combineDf(df1,*dfs): 
    for dfi in dfs:
        df1 = df1.append(dfi, ignore_index=True)
    return df1

#输出数据
str_data = '/home/sunmd/stock/shuju.xlsx'
#str_data = r'C:\Users\sun-m\Desktop\stock\shuju.xlsx'

#输入路径
file_path = r'/home/sunmd/stock/'
#file_path = 'C:/Users/sun-m/Desktop/stock/'

#固定的列名
columns_name = ['代码', '名称', '涨幅%', '净流入', '大流入', '大流出', '中流入', '中流出', '统计时间']
#读数据表
def read_data():
    return pd.read_excel(str_data)

#写数据表
def save_data(df):
    df.to_excel(str_data)
    
#导入一天的数据
def save_one_day(file_date, columns_name, num):
    df = read_data()
    df_one = loadExcFac(file_path, file_date, columns_name, [num])
    df = combineDf(df, df_one)
    df[columns_name[3:-1]] = df[columns_name[3:-1]].astype(np.int64)
    df.drop_duplicates(inplace=True)
    save_data(df)
    return df

#输出样式
df = read_data()
def rl_style(s):
    lst = []
    if s['涨幅%'] < 0:
        color = 'green'
    elif s['涨幅%'] > 0:
        color = 'red'
    else:
        color = 'white'
    lst.append('color:%s' % color)
    
    if s['净流入'] < 0:
        color = 'green'
    elif s['净流入'] > 0:
        color = 'red'
    else:
        color = 'white'
    lst.append('color:%s' % color)
    
    lst.append('color:red')
    lst.append('color:green')
    lst.append('color:red')
    lst.append('color:green')
    return lst

#数据样式
#print(df['涨幅%'].astype(np.float))
mystl = df.style.apply(rl_style,axis=1, subset=['涨幅%', '净流入',
                                        '大流入', '大流出',
                                        '中流入', '中流出']).format({'涨幅%':"{:+.2%}"}).\
bar(subset=['涨幅%','净流入'], align='mid', color=['#5fba7d', '#d65f5f'], width=100)

#数值标准化
def col_normalizy(df, *cols):
    temp_str = '_nor'
    for col in cols:
        df[col + temp_str] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())
    return df

#涨幅和净流入图标回执
def zf_jlr(df, name, png_name):
    fig,axis = plt.subplots(1,2, figsize=(16,8))
    df['涨幅%'].plot(kind='bar', ax=axis[0], alpha=0.8, title=name + '涨幅统计', rot=45, fontsize=(15))
    df['净流入'].plot(kind='bar', ax=axis[1], alpha=0.8, title=name + '净流入统计', rot=45, fontsize=(15))
    print(file_path+png_name + "保存路径")
    plt.savefig(file_path+png_name, dpi=400)
    print('保存成功')

#饼图回执
def draw_pie(df, name, png_name):
    fig,axis = plt.subplots(1,1, figsize=(8,8))
    plt.title(name)
    plt.fontsize = 15
    plt.pie(df,
           labels = s.index,
           autopct='%.2f%%',
           pctdistance=0.6,
           labeldistance = 1.2,
           startangle=0,
           radius=1.5,
           frame=False)
    print(file_path+png_name + "保存路径")
    fig.subplots_adjust(right=0.7, top=0.7 )  
    plt.savefig(file_path+png_name,dpi=400)
    print('保存成功')

#异常值
#查询异常值
def detectoutliers2(list):
 
    outlier_indices = []  
    # iterate over features(columns)  
  
        # 1st quartile (25%)  
    Q1 = list.quantile(q=0.25)
    # 3rd quartile (75%)  
    Q3 = list.quantile(0.75)  
    # Interquartile range (IQR)  
    IQR = Q3 - Q1  
    # outlier step  
    outlier_step = 1.5 * IQR  
    # Determine a list of indices of outliers for feature col  
    outlier_list_col = list[(list < Q1 - outlier_step) | (list > Q3 + outlier_step )]  
  
    return outlier_list_col 

#异常值进行统计
def ycz():
    df_grp_name = df.groupby('名称').sum()
    name_list = df_grp_name.index
    #建立空的df
    outliers_list_zf = pd.DataFrame(columns=columns_name)
    #涨幅异常值
    for name in name_list:
        lst = detectoutliers2(df[df['名称'] == name]['涨幅%'].sort_values())
        outliers_list_zf = outliers_list_zf.append(df[df['名称'] == name][df[df['名称'] == name]['涨幅%']\
                                                                       .isin(lst)], ignore_index=False)
    outliers_list_zf.drop_duplicates(inplace=True)
    
    #净流入异常值
    
    #建立空的df
    outliers_list_jlr = pd.DataFrame(columns=columns_name)
    
    #净流入异常值
    for name in name_list:
        lst = detectoutliers2(df[df['名称'] == name]['净流入'].sort_values())
        outliers_list_jlr = outliers_list_jlr.append(df[df['名称'] == name][df[df['名称'] == name]['净流入']\
                                                                    .isin(lst)], ignore_index=False)
    outliers_list_jlr.drop_duplicates(inplace=True)
    
    return [outliers_list_zf, outliers_list_jlr]

# %%
file_date = '2019-01'

to_day = '2019-01-17'

df = save_one_day( file_date, columns_name, 17)

df[df['统计时间']=='2019-01-17'].head()
# Out:
#            代码      名称     涨幅%        净流入         大流入         大流出         中流入  \
# 10322  881154    园区开发  0.0263  605915440   780748110   363687909   761166730
# 10323  881105  煤炭开采加工  0.0181  461623880  1292435660   953104270  1238450870
# 10324  881112      钢铁  0.0031  457484450   982472540   623578830   737668220
# 10325  881156   保险及其他 -0.0075  299816000  2059444610  1664882510  1547768700
# 10326  881155      银行 -0.0050  116809750  2022653460  1927420980  1360672700
#
#               中流出        统计时间
# 10322   572311490  2019-01-17
# 10323  1116158380  2019-01-17
# 10324   639077480  2019-01-17
# 10325  1642514800  2019-01-17
# 10326  1339095430  2019-01-17

# %%
df[df['统计时间']==to_day].sort_values('净流入',ascending=False)\
.style.use(mystl.export()).format({'涨幅%':"{:+.2%}"})
# Out:
# <style  type="text/css" >
#     #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.4%, #d65f5f 46.4%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.4%, #d65f5f 46.4%, #d65f5f 83.3%, transparent 83.3%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 95.2%, transparent 95.2%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row2_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.4%, #d65f5f 46.4%, #d65f5f 52.7%, transparent 52.7%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row2_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 95.0%, transparent 95.0%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row3_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.2%, #5fba7d 31.2%, #5fba7d 46.4%, transparent 46.4%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 89.7%, transparent 89.7%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row4_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 36.3%, #5fba7d 36.3%, #5fba7d 46.4%, transparent 46.4%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 83.6%, transparent 83.6%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row5_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.6%, #5fba7d 35.6%, #5fba7d 46.4%, transparent 46.4%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row5_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 81.8%, transparent 81.8%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row6_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.4%, #d65f5f 46.4%, #d65f5f 65.6%, transparent 65.6%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row6_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 81.2%, transparent 81.2%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.5%, #5fba7d 40.5%, #5fba7d 46.4%, transparent 46.4%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row7_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 80.7%, transparent 80.7%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.3%, #5fba7d 37.3%, #5fba7d 46.4%, transparent 46.4%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row8_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 79.6%, #d65f5f 79.6%, #d65f5f 80.4%, transparent 80.4%);
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_a6909dca_1a29_11e9_9e1e_3052cb810eb9row8_col5 {
#             color: green;
#         }

# %%
#按分类进行统计

df_grp_name = df[df['统计时间']>=file_date+'-03'].groupby('名称').sum()
df_grp_name.sort_values(['涨幅%','净流入'], ascending=False)\
.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row0_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row0_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 82.3%, #5fba7d 82.3%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row0_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row0_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row1_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 81.2%, transparent 81.2%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row1_col1 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 84.3%, #d65f5f 84.3%, #d65f5f 88.6%, transparent 88.6%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row1_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row1_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row2_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 76.4%, transparent 76.4%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row2_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #5fba7d 48.0%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row2_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row2_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row3_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 73.6%, transparent 73.6%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row3_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 75.3%, #5fba7d 75.3%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row3_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row3_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row4_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 63.4%, transparent 63.4%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row4_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 65.7%, #5fba7d 65.7%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row4_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row4_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row5_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 57.4%, transparent 57.4%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row5_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.8%, #5fba7d 76.8%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row5_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row5_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row6_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 57.2%, transparent 57.2%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row6_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 73.3%, #5fba7d 73.3%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row6_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row6_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row7_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 57.1%, transparent 57.1%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row7_col1 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 84.3%, #d65f5f 84.3%, #d65f5f 93.2%, transparent 93.2%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row7_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row7_col3 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row8_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #d65f5f 0.0%, #d65f5f 56.4%, transparent 56.4%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row8_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 57.4%, #5fba7d 57.4%, #5fba7d 84.3%, transparent 84.3%);
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row8_col2 {
#             color: red;
#         }    #T_a812547c_1a29_11e9_9e1e_3052cb810eb9row8_col3 {
#             color: green;
#         }    #T_a812547c_1a

# %%
#按时间进行统计
df_grp_time = df.groupby('统计时间').sum()
df_grp_time.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})

zf_jlr(df_grp_time[-10:], "按时间进行", "1.png")

#大资金流入饼图
s = df[df['统计时间']==to_day]['大流入']
s.index = df[df['统计时间']==to_day]['名称']

s = s.sort_values(ascending=False)[:10]
draw_pie(s, '今天大资金流入', '2.png')

#大资金流出饼图
s = df[df['统计时间']==to_day]['大流出']
s.index = df[df['统计时间']==to_day]['名称']

s = s.sort_values(ascending=False)[:10]
draw_pie(s, '今天大资金流出', '3.png')

#按分类进行统计
df_grp_name = df[df['统计时间']>='2019-01-01'].groupby('名称').sum()
df_grp_name.sort_values(['涨幅%','净流入'], ascending=False)\
.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})

#前五净流入
df_grp_name_f = df_grp_name.sort_values(['净流入','涨幅%'], ascending=False)
zf_jlr(df_grp_name_f.iloc[:10], '前五资金流入', '4.png')

#后5净流入
df_grp_name_b = df_grp_name.sort_values(['净流入','涨幅%'])
zf_jlr(df_grp_name_b.iloc[:10], '后五资金流入', '5.png')

#异常值
lst = ycz()

outliers_list_zf = lst[0]
outliers_list_jlr = lst[1]

if not outliers_list_zf[outliers_list_zf['统计时间'] == to_day].empty:
    temp_zf = outliers_list_zf[outliers_list_zf['统计时间'] == to_day]
    num = 0
    for name in temp_zf['名称']:
        df_yczf = df[df['名称']==name]
        df_yczf.index = df_yczf['统计时间']
        zf_jlr(df_yczf[-10:], '异常涨幅板块-' + name, 'ycz_zf' + str(num) +  '.png')
        num = num + 1
        
if not outliers_list_jlr[outliers_list_jlr['统计时间'] == to_day].empty:

    temp_jlr = outliers_list_jlr[outliers_list_jlr['统计时间'] == to_day]
    num = 0
    for name in temp_jlr['名称']:
        df_ycjlr = df[df['名称']==name]
        df_ycjlr.index = df_ycjlr['统计时间']
        zf_jlr(df_ycjlr[-10:], '异常净流入板块-' + name, 'ycz_jlr' + str(num) +  '.png')
        num = num + 1
# Out:
# /home/sunmd/stock/1.png保存路径
# 保存成功
# /home/sunmd/stock/2.png保存路径
# 保存成功
# /home/sunmd/stock/3.png保存路径
# 保存成功
# /home/sunmd/stock/4.png保存路径
# 保存成功
# /home/sunmd/stock/5.png保存路径
# 保存成功
# /home/sunmd/stock/ycz_jlr0.png保存路径
# 保存成功
# /home/sunmd/stock/ycz_jlr1.png保存路径
# 保存成功

# %%
#单个板块进行查看
df[df['名称'] == '房地产开发'].style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_018847f8_127a_11e9_ae18_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.4%, #d65f5f 60.4%, #d65f5f 65.7%, transparent 65.7%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row0_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 59.3%, #5fba7d 59.3%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.4%, #d65f5f 60.4%, #d65f5f 65.7%, transparent 65.7%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row1_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 59.3%, #5fba7d 59.3%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 56.6%, #5fba7d 56.6%, #5fba7d 60.4%, transparent 60.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.2%, #5fba7d 43.2%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row3_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.4%, #d65f5f 60.4%, #d65f5f 63.4%, transparent 63.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 59.8%, #d65f5f 59.8%, #d65f5f 65.4%, transparent 65.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row4_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.4%, #d65f5f 60.4%, #d65f5f 63.4%, transparent 63.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 59.8%, #d65f5f 59.8%, #d65f5f 65.4%, transparent 65.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row5_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.4%, #d65f5f 60.4%, #d65f5f 64.8%, transparent 64.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.8%, #5fba7d 43.8%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 58.2%, #5fba7d 58.2%, #5fba7d 60.4%, transparent 60.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 17.8%, #5fba7d 17.8%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.8%, #5fba7d 51.8%, #5fba7d 60.4%, transparent 60.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.6%, #5fba7d 27.6%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row8_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 60.4%, #d65f5f 60.4%, #d65f5f 61.4%, transparent 61.4%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.5%, #5fba7d 45.5%, #5fba7d 59.8%, transparent 59.8%);
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_018847f8_127a_11e9_ae18_3052cb810eb9row8_col5 {
#             color: green;

# %%
outliers_list_zf.drop_duplicates().sort_values('统计时间').style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_09713c36_127a_11e9_ae18_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.2%, #d65f5f 48.2%, #d65f5f 62.7%, transparent 62.7%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 61.1%, transparent 61.1%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.2%, #d65f5f 48.2%, #d65f5f 89.1%, transparent 89.1%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 51.7%, transparent 51.7%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row2_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.2%, #d65f5f 48.2%, #d65f5f 62.7%, transparent 62.7%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row2_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 61.1%, transparent 61.1%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row3_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 28.5%, #5fba7d 28.5%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row3_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.0%, #5fba7d 27.0%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row4_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 23.5%, #5fba7d 23.5%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row4_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.0%, #5fba7d 35.0%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row5_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.1%, #5fba7d 30.1%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.7%, #5fba7d 45.7%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 24.4%, #5fba7d 24.4%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.8%, #5fba7d 40.8%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 24.2%, #5fba7d 24.2%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.6%, #5fba7d 45.6%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 25.6%, #5fba7d 25.6%, #5fba7d 48.2%, transparent 48.2%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 41.4%, #5fba7d 41.4%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_09713c36_127a_11e9_ae18_3052cb810eb9row8_col5 {
#             color: green;

# %%
outliers_list_jlr.drop_duplicates().sort_values('统计时间').style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 54.1%, transparent 54.1%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 48.9%, transparent 48.9%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 54.1%, transparent 54.1%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 48.9%, transparent 48.9%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.2%, #5fba7d 48.2%, #5fba7d 52.5%, transparent 52.5%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 39.1%, #5fba7d 39.1%, #5fba7d 48.0%, transparent 48.0%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row3_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 67.7%, transparent 67.7%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 49.4%, transparent 49.4%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row4_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 58.4%, transparent 58.4%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 50.1%, transparent 50.1%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row5_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 67.5%, transparent 67.5%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row5_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 59.9%, transparent 59.9%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row6_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 99.4%, transparent 99.4%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row6_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 51.7%, transparent 51.7%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row7_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 62.7%, transparent 62.7%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row7_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 50.3%, transparent 50.3%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row8_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.5%, #d65f5f 52.5%, #d65f5f 69.2%, transparent 69.2%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row8_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.0%, #d65f5f 48.0%, #d65f5f 61.1%, transparent 61.1%);
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_381d8fd0_fddf_11e8_9cbb_3052cb810eb9row8_col5 {
#             color: green;
#         }    #T_381d8
