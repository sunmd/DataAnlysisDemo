# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['KaiTi']
mpl.rcParams['font.serif'] = ['KaiTi']
mpl.rcParams['axes.unicode_minus']=False

import matplotlib.style as psl
print(plt.style.available)
# 查看样式列表
psl.use('ggplot')

% matplotlib inline
# Out:
# ['seaborn-dark', 'Solarize_Light2', 'seaborn-darkgrid', 'seaborn-paper', 'seaborn-poster', 'bmh', 'ggplot', 'seaborn-talk', 'seaborn-whitegrid', 'classic', 'grayscale', 'seaborn-dark-palette', 'fast', 'seaborn-deep', 'seaborn-white', 'seaborn-muted', 'seaborn-ticks', 'dark_background', 'seaborn-notebook', 'seaborn-colorblind', '_classic_test', 'fivethirtyeight', 'seaborn-bright', 'seaborn', 'seaborn-pastel']

# %%
#读取数据xls的数据,其实为csv的文件
def loadCsv(file,date_time):
    dataf = pd.read_csv(file, encoding='GB18030', delimiter='\t', header=1).drop('Unnamed: 8', axis=1)
    dataf['savetime'] = pd.to_datetime(date_time).strftime('%Y-%m-%d')
    return dataf

#读取数据xls的数据，真实xls
def loadExl(file,date_time):
    dataf = pd.read_excel(file, encoding='utf8', header=1)
    dataf['savetime'] = pd.to_datetime(date_time).strftime('%Y-%m-%d')
    return dataf

#列名重新定义
def reName(df, n):
    df.columns = n
    return df

#文件合成工厂(软件导出数据)
def loadExcFac(path,date_time,columnsName,nums):
    name1 = 'Table'
    name2 = '.xls'
    shuju = pd.DataFrame(columns=columnsName)
    for i in nums:
        name = path + name1 + str(i) + name2
        dateTime = date_time + '-' + str(i)
        df = loadCsv(name, dateTime)
        df = reName(df, columnsName)
        df['涨幅%'] = df['涨幅%'].str.strip("%").astype(float)/100
        shuju = shuju.append(df, ignore_index=True)
    return shuju

#文件合成工厂(手动调整的xls)
def loadExc2Fac(path,date_time,columnsName,nums):
    name1 = 'Table'
    name2 = '.xls'
    shuju = pd.DataFrame(columns=columnsName)
    for i in nums:
        name = path + name1 + str(i) + name2
        dateTime = date_time + '-' + str(i)
        df = loadExl(name, dateTime)
        df = reName(df, columnsName)
        df['涨幅%'] = df['涨幅%']
        shuju = shuju.append(df, ignore_index=True)
    return shuju

#合并数据
def combineDf(df1,*dfs): 
    for dfi in dfs:
        df1 = df1.append(dfi, ignore_index=True)
    return df1

#输出数据
str_data = '/home/sunmd/stock/shuju.xlsx'
#str_data = r'C:\Users\sun-m\Desktop\stock\shuju.xlsx'

#输入路径
file_path = r'/home/sunmd/stock/'
#file_path = 'C:/Users/sun-m/Desktop/stock/'

#固定的列名
columns_name = ['代码', '名称', '涨幅%', '净流入', '大流入', '大流出', '中流入', '中流出', '统计时间']
#读数据表
def read_data():
    return pd.read_excel(str_data)

#写数据表
def save_data(df):
    df.to_excel(str_data)
    
#导入一天的数据
def save_one_day(file_date, columns_name, num):
    df = read_data()
    df_one = loadExcFac(file_path, file_date, columns_name, [num])
    df = combineDf(df, df_one)
    df[columns_name[3:-1]] = df[columns_name[3:-1]].astype(np.int64)
    df.drop_duplicates(inplace=True)
    save_data(df)
    return df

#输出样式
df = read_data()
def rl_style(s):
    lst = []
    if s['涨幅%'] < 0:
        color = 'green'
    elif s['涨幅%'] > 0:
        color = 'red'
    else:
        color = 'white'
    lst.append('color:%s' % color)
    
    if s['净流入'] < 0:
        color = 'green'
    elif s['净流入'] > 0:
        color = 'red'
    else:
        color = 'white'
    lst.append('color:%s' % color)
    
    lst.append('color:red')
    lst.append('color:green')
    lst.append('color:red')
    lst.append('color:green')
    return lst

#数据样式
#print(df['涨幅%'].astype(np.float))
mystl = df.style.apply(rl_style,axis=1, subset=['涨幅%', '净流入',
                                        '大流入', '大流出',
                                        '中流入', '中流出']).format({'涨幅%':"{:+.2%}"}).\
bar(subset=['涨幅%','净流入'], align='mid', color=['#5fba7d', '#d65f5f'], width=100)

#数值标准化
def col_normalizy(df, *cols):
    temp_str = '_nor'
    for col in cols:
        df[col + temp_str] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())
    return df

#涨幅和净流入图标回执
def zf_jlr(df, name, png_name):
    fig,axis = plt.subplots(1,2, figsize=(16,8))
    df['涨幅%'].plot(kind='bar', ax=axis[0], alpha=0.8, title=name + '涨幅统计', rot=45, fontsize=(15))
    df['净流入'].plot(kind='bar', ax=axis[1], alpha=0.8, title=name + '净流入统计', rot=45, fontsize=(15))
    print(file_path+png_name + "保存路径")
    plt.savefig(file_path+png_name, dpi=400)
    print('保存成功')

#饼图回执
def draw_pie(df, name, png_name):
    fig,axis = plt.subplots(1,1, figsize=(8,8))
    plt.title(name)
    plt.fontsize = 15
    plt.pie(df,
           labels = s.index,
           autopct='%.2f%%',
           pctdistance=0.6,
           labeldistance = 1.2,
           startangle=0,
           radius=1.5,
           frame=False)
    print(file_path+png_name + "保存路径")
    fig.subplots_adjust(right=0.7, top=0.7 )  
    plt.savefig(file_path+png_name,dpi=400)
    print('保存成功')

#异常值
#查询异常值
def detectoutliers2(list):
 
    outlier_indices = []  
    # iterate over features(columns)  
  
        # 1st quartile (25%)  
    Q1 = list.quantile(q=0.25)
    # 3rd quartile (75%)  
    Q3 = list.quantile(0.75)  
    # Interquartile range (IQR)  
    IQR = Q3 - Q1  
    # outlier step  
    outlier_step = 1.5 * IQR  
    # Determine a list of indices of outliers for feature col  
    outlier_list_col = list[(list < Q1 - outlier_step) | (list > Q3 + outlier_step )]  
  
    return outlier_list_col 

#异常值进行统计
def ycz():
    df_grp_name = df.groupby('名称').sum()
    name_list = df_grp_name.index
    #建立空的df
    outliers_list_zf = pd.DataFrame(columns=columns_name)
    #涨幅异常值
    for name in name_list:
        lst = detectoutliers2(df[df['名称'] == name]['涨幅%'].sort_values())
        outliers_list_zf = outliers_list_zf.append(df[df['名称'] == name][df[df['名称'] == name]['涨幅%']\
                                                                       .isin(lst)], ignore_index=False)
    outliers_list_zf.drop_duplicates(inplace=True)
    
    #净流入异常值
    
    #建立空的df
    outliers_list_jlr = pd.DataFrame(columns=columns_name)
    
    #净流入异常值
    for name in name_list:
        lst = detectoutliers2(df[df['名称'] == name]['净流入'].sort_values())
        outliers_list_jlr = outliers_list_jlr.append(df[df['名称'] == name][df[df['名称'] == name]['净流入']\
                                                                    .isin(lst)], ignore_index=False)
    outliers_list_jlr.drop_duplicates(inplace=True)
    
    return [outliers_list_zf, outliers_list_jlr]

# %%
file_date = '2018-06'

to_day = '2018-06-08'

df = save_one_day( file_date, columns_name, 8)

df[df['统计时间']=='2018-06-08'].head()
# Out:
#           代码      名称     涨幅%        净流入         大流入         大流出         中流入  \
# 1251  881123    其他电子 -0.0039  222760110   950684040   733914940   816562480
# 1252  881142    生物制品 -0.0000   83516190  1159311700  1132571510  1088423440
# 1253  881154    园区开发 -0.0072  -17286462    33364876    42234498   102681759
# 1254  881150      公交 -0.0218  -44817882     9150409    22225527    35934803
# 1255  881106  石油矿业开采 -0.0188  -60901121    81760556   111664172   112206735
#
#              中流出        统计时间
# 1251   810571470  2018-06-08
# 1252  1031647440  2018-06-08
# 1253   111098599  2018-06-08
# 1254    67677567  2018-06-08
# 1255   143204240  2018-06-08

# %%
df[df['统计时间']==to_day].sort_values('净流入',ascending=False)\
.style.use(mystl.export()).format({'涨幅%':"{:+.2%}"})
# Out:
# <style  type="text/css" >
#     #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row0_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.1%, #5fba7d 67.1%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.6%, #d65f5f 93.6%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row1_col2 {
#             color: white;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 78.7%, #5fba7d 78.7%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.6%, #d65f5f 93.6%, #d65f5f 96.0%, transparent 96.0%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 57.2%, #5fba7d 57.2%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.1%, #5fba7d 93.1%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row3_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 13.5%, #5fba7d 13.5%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row3_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 92.3%, #5fba7d 92.3%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row4_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 22.5%, #5fba7d 22.5%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row4_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 91.8%, #5fba7d 91.8%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row5_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 71.6%, #5fba7d 71.6%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 91.8%, #5fba7d 91.8%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 73.1%, #5fba7d 73.1%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 91.6%, #5fba7d 91.6%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 36.5%, #5fba7d 36.5%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 90.9%, #5fba7d 90.9%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.1%, #5fba7d 67.1%, #5fba7d 78.7%, transparent 78.7%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 90.4%, #5fba7d 90.4%, #5fba7d 93.6%, transparent 93.6%);
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_078a53ec_6b1f_11e8_bee5_3052cb810eb9row8_col5 {
#             color

# %%
#按分类进行统计

df_grp_name = df[df['统计时间']>file_date+'-01'].groupby('名称').sum()
df_grp_name.sort_values(['涨幅%','净流入'], ascending=False)\
.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row0_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row0_col1 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 74.0%, #d65f5f 74.0%, #d65f5f 76.1%, transparent 76.1%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row0_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row0_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row1_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 90.0%, transparent 90.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row1_col1 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 74.0%, #d65f5f 74.0%, #d65f5f 90.0%, transparent 90.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row1_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row1_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row2_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 75.2%, transparent 75.2%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row2_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 70.9%, #5fba7d 70.9%, #5fba7d 74.0%, transparent 74.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row2_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row2_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row3_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 67.1%, transparent 67.1%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row3_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 72.7%, #5fba7d 72.7%, #5fba7d 74.0%, transparent 74.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row3_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row3_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row4_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 66.1%, transparent 66.1%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row4_col1 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 74.0%, #d65f5f 74.0%, #d65f5f 90.6%, transparent 90.6%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row4_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row4_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row5_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 62.7%, transparent 62.7%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row5_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 68.8%, #5fba7d 68.8%, #5fba7d 74.0%, transparent 74.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row5_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row5_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row6_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 61.7%, transparent 61.7%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row6_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.0%, #5fba7d 27.0%, #5fba7d 74.0%, transparent 74.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row6_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row6_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row7_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 58.9%, transparent 58.9%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row7_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 58.3%, #5fba7d 58.3%, #5fba7d 74.0%, transparent 74.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row7_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row7_col3 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row8_col0 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.4%, #d65f5f 33.4%, #d65f5f 57.3%, transparent 57.3%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row8_col1 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.7%, #5fba7d 31.7%, #5fba7d 74.0%, transparent 74.0%);
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row8_col2 {
#             color: red;
#         }    #T_436e64a2_6b1f_11e8_bee5_3052cb810eb9row8_col3 {
#             color: green;
#         }

# %%
#按时间进行统计
df_grp_time = df.groupby('统计时间').sum()
df_grp_time.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})

zf_jlr(df_grp_time[-10:], "按时间进行", "1.png")

#大资金流入饼图
s = df[df['统计时间']==to_day]['大流入']
s.index = df[df['统计时间']==to_day]['名称']

s = s.sort_values(ascending=False)[:10]
draw_pie(s, '今天大资金流入', '2.png')

#大资金流出饼图
s = df[df['统计时间']==to_day]['大流出']
s.index = df[df['统计时间']==to_day]['名称']

s = s.sort_values(ascending=False)[:10]
draw_pie(s, '今天大资金流出', '3.png')

#按分类进行统计
df_grp_name = df[df['统计时间']>file_date+'-01'].groupby('名称').sum()
df_grp_name.sort_values(['涨幅%','净流入'], ascending=False)\
.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})

#前五净流入
df_grp_name_f = df_grp_name.sort_values(['净流入','涨幅%'], ascending=False)
zf_jlr(df_grp_name_f.iloc[:10], '前五资金流入', '4.png')

#后5净流入
df_grp_name_b = df_grp_name.sort_values(['净流入','涨幅%'])
zf_jlr(df_grp_name_b.iloc[:10], '后五资金流入', '5.png')

#异常值
lst = ycz()

outliers_list_zf = lst[0]
outliers_list_jlr = lst[1]

if not outliers_list_zf[outliers_list_zf['统计时间'] == to_day].empty:
    temp_zf = outliers_list_zf[outliers_list_zf['统计时间'] == to_day]
    num = 0
    for name in temp_zf['名称']:
        df_yczf = df[df['名称']==name]
        df_yczf.index = df_yczf['统计时间']
        zf_jlr(df_yczf[-10:], '异常涨幅板块-' + name, 'ycz_zf' + str(num) +  '.png')
        num = num + 1
        
if not outliers_list_jlr[outliers_list_jlr['统计时间'] == to_day].empty:

    temp_jlr = outliers_list_jlr[outliers_list_jlr['统计时间'] == to_day]
    num = 0
    for name in temp_jlr['名称']:
        df_ycjlr = df[df['名称']==name]
        df_ycjlr.index = df_ycjlr['统计时间']
        zf_jlr(df_ycjlr[-10:], '异常净流入板块-' + name, 'ycz_jlr' + str(num) +  '.png')
        num = num + 1
# Out:
# /home/sunmd/stock/1.png保存路径
# 保存成功
# /home/sunmd/stock/2.png保存路径
# 保存成功
# /home/sunmd/stock/3.png保存路径
# 保存成功
# /home/sunmd/stock/4.png保存路径
# 保存成功
# /home/sunmd/stock/5.png保存路径
# 保存成功
# /home/sunmd/stock/ycz_zf0.png保存路径
# 保存成功
# /home/sunmd/stock/ycz_zf1.png保存路径
# 保存成功

# %%
#单个板块进行查看
df[df['名称'] == '保险及其他'].style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_2559258e_699d_11e8_bee5_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.2%, #d65f5f 76.2%, #d65f5f 80.3%, transparent 80.3%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row0_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.2%, #d65f5f 76.2%, #d65f5f 80.3%, transparent 80.3%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row1_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.5%, #5fba7d 32.5%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 55.6%, #5fba7d 55.6%, #5fba7d 76.2%, transparent 76.2%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 1.0%, #5fba7d 1.0%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row3_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.2%, #d65f5f 76.2%, #d65f5f 93.8%, transparent 93.8%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.0%, #d65f5f 45.0%, #d65f5f 61.6%, transparent 61.6%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row4_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.2%, #d65f5f 76.2%, #d65f5f 93.8%, transparent 93.8%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.0%, #d65f5f 45.0%, #d65f5f 61.6%, transparent 61.6%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row5_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.2%, #d65f5f 76.2%, #d65f5f 98.1%, transparent 98.1%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 44.2%, #5fba7d 44.2%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 71.5%, #5fba7d 71.5%, #5fba7d 76.2%, transparent 76.2%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 10.4%, #5fba7d 10.4%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 40.7%, #5fba7d 40.7%, #5fba7d 76.2%, transparent 76.2%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 62.2%, #5fba7d 62.2%, #5fba7d 76.2%, transparent 76.2%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 22.6%, #5fba7d 22.6%, #5fba7d 45.0%, transparent 45.0%);
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_2559258e_699d_11e8_bee5_3052cb810eb9row8_col5 {
#             color: green;

# %%
#整体版本的调查
fig_time,axis_time = plt.subplots(1,2, figsize=(16,8))

df_grp_time['涨幅%'].plot(kind='bar', ax=axis_time[0], alpha=0.8, title='涨幅统计')

df_grp_time['净流入'].plot(kind='bar', ax=axis_time[1], alpha=0.8, title='净流入')
plt.savefig(r'C:\Users\sun-m\Desktop\stock\DataAnlysisDemo-master\pic.png',
            dpi=400,
            bbox_inches = 'tight')

# %%
df_gx = df.copy()
df_gx.index = df_gx['统计时间']

#列出每个模块的涨幅和净流入
#name_list = df_grp_name.index
name_list = ['计算机应用', '保险及其他', '饮料制造']
fig_gg, axis_gg = plt.subplots(len(name_list), 2, figsize=(16,10*len(name_list)))
num = 0
for name in name_list:
    temp_df = df_gx[df_gx['名称'] == name]
    temp_df['涨幅%'].plot(kind='bar', alpha=0.8, ax=axis_gg[num][0], rot=45, title=name+'-涨幅')
    temp_df['净流入'].plot(kind='bar', alpha=0.8, ax=axis_gg[num][1], rot=45, title=name+'-净流入')
    num = num + 1
    plt.savefig(r'C:\Users\sun-m\Desktop\stock\DataAnlysisDemo-master\pic'+str(num)+'.png',
            dpi=400,
            bbox_inches = 'tight')
#for name in name_list:
#    print(df_gx[df_gx['名称'] == name]['涨幅%'].head())

# %%
outliers_list_zf.drop_duplicates().style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow0_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 11.0%, #5fba7d 11.0%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow0_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.0%, #5fba7d 27.0%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow0_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow0_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow0_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow0_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow1_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 4.8%, #5fba7d 4.8%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow1_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.9%, #5fba7d 51.9%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow1_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow1_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow1_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow1_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 14.2%, #5fba7d 14.2%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.6%, #5fba7d 31.6%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow2_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow2_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow2_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow2_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow3_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 17.1%, #5fba7d 17.1%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow3_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 35.0%, #5fba7d 35.0%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow3_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow3_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow3_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow3_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow4_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 12.0%, #5fba7d 12.0%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow4_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 20.2%, #5fba7d 20.2%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow4_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow4_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow4_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow4_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow5_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 13.2%, #5fba7d 13.2%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 54.9%, #5fba7d 54.9%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow5_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow5_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow5_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow5_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 20.0%, #5fba7d 20.0%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 50.7%, #5fba7d 50.7%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow6_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow6_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow6_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow6_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 17.6%, #5fba7d 17.6%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.1%, #5fba7d 51.1%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow7_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow7_col5 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow7_col6 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow7_col7 {
#             color: green;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 11.8%, #5fba7d 11.8%, #5fba7d 44.6%, transparent 44.6%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 0.0%, #5fba7d 0.0%, #5fba7d 55.9%, transparent 55.9%);
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow8_col4 {
#             color: red;
#         }    #T_0b30b5e8_67d7_11e8_aa09_74e5f9d3823arow8_col5 {
#             color:

# %%
outliers_list_jlr.sort_values('统计时间').drop_duplicates().style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 39.6%, transparent 39.6%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 65.1%, transparent 65.1%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow0_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow0_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow0_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow0_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 39.6%, transparent 39.6%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 65.1%, transparent 65.1%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow1_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow1_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow1_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow1_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow2_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 57.8%, transparent 57.8%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow2_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 66.0%, transparent 66.0%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow2_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow2_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow2_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow2_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow3_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 61.8%, transparent 61.8%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 71.0%, transparent 71.0%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow3_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow3_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow3_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow3_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow4_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 45.9%, transparent 45.9%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 66.6%, transparent 66.6%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow4_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow4_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow4_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow4_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow5_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow5_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 69.8%, transparent 69.8%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow5_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow5_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow5_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow5_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow6_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 57.5%, transparent 57.5%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow6_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 83.2%, transparent 83.2%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow6_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow6_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow6_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow6_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow7_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 59.7%, transparent 59.7%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow7_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 85.2%, transparent 85.2%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow7_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow7_col5 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow7_col6 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow7_col7 {
#             color: green;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow8_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 37.5%, #d65f5f 37.5%, #d65f5f 61.8%, transparent 61.8%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow8_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 63.8%, #d65f5f 63.8%, #d65f5f 71.0%, transparent 71.0%);
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow8_col4 {
#             color: red;
#         }    #T_026ab3d8_67d7_11e8_a3a5_74e5f9d3823arow8_col5 {
#             color: green;
#         }    #T_026ab3d

# %%
df_merge = outliers_list_zf.merge(outliers_list_jlr, how='inner')
df_merge.sort_values('统计时间').style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fb7c0975dad6> in <module>()
# ----> 1 df_merge = outliers_list_zf.merge(outliers_list_jlr, how='inner')
#       2 df_merge.sort_values('统计时间').style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
#
# NameError: name 'outliers_list_zf' is not defined

# %%
import os
for filename in os.listdir(file_path):
    if 'ycz_jlr' in filename:
        print('+++++++')
        print(filename, type(filename))
    if 'ycz_zf' in filename:
        print('-------')
        print(filename, type(filename))
# Out:
# +++++++
# ycz_jlr0.png <class 'str'>
# +++++++
# ycz_jlr1.png <class 'str'>

# %%
s = pd.DataFrame([1,2,3,4,5,6,7,8,9],columns = ['value'])
s.cumsum()
# Out:
#    value
# 0      1
# 1      3
# 2      6
# 3     10
# 4     15
# 5     21
# 6     28
# 7     36
# 8     45
