# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import matplotlib as mpl
mpl.rcParams['font.sans-serif'] = ['KaiTi']
mpl.rcParams['font.serif'] = ['KaiTi']
mpl.rcParams['axes.unicode_minus']=False

import matplotlib.style as psl
print(plt.style.available)
# 查看样式列表
psl.use('ggplot')

% matplotlib inline
# Out:
# ['seaborn-dark', 'Solarize_Light2', 'seaborn-darkgrid', 'seaborn-paper', 'seaborn-poster', 'bmh', 'ggplot', 'seaborn-talk', 'seaborn-whitegrid', 'classic', 'grayscale', 'seaborn-dark-palette', 'fast', 'seaborn-deep', 'seaborn-white', 'seaborn-muted', 'seaborn-ticks', 'dark_background', 'seaborn-notebook', 'seaborn-colorblind', '_classic_test', 'fivethirtyeight', 'seaborn-bright', 'seaborn', 'seaborn-pastel']

# %%
#读取数据xls的数据,其实为csv的文件
def loadCsv(file,date_time):
    dataf = pd.read_csv(file, encoding='GB18030', delimiter='\t', header=1).drop('Unnamed: 8', axis=1)
    dataf['savetime'] = pd.to_datetime(date_time).strftime('%Y-%m-%d')
    return dataf

#读取数据xls的数据，真实xls
def loadExl(file,date_time):
    dataf = pd.read_excel(file, encoding='utf8', header=1)
    dataf['savetime'] = pd.to_datetime(date_time).strftime('%Y-%m-%d')
    return dataf

#列名重新定义
def reName(df, n):
    df.columns = n
    return df

#文件合成工厂(软件导出数据)
def loadExcFac(path,date_time,columnsName,nums):
    name1 = 'Table'
    name2 = '.xls'
    shuju = pd.DataFrame(columns=columnsName)
    for i in nums:
        name = path + name1 + str(i) + name2
        dateTime = date_time + '-' + str(i)
        df = loadCsv(name, dateTime)
        df = reName(df, columnsName)
        df['涨幅%'] = df['涨幅%'].str.strip("%").astype(float)/100
        shuju = shuju.append(df, ignore_index=True)
    return shuju

#文件合成工厂(手动调整的xls)
def loadExc2Fac(path,date_time,columnsName,nums):
    name1 = 'Table'
    name2 = '.xls'
    shuju = pd.DataFrame(columns=columnsName)
    for i in nums:
        name = path + name1 + str(i) + name2
        dateTime = date_time + '-' + str(i)
        df = loadExl(name, dateTime)
        df = reName(df, columnsName)
        df['涨幅%'] = df['涨幅%']
        shuju = shuju.append(df, ignore_index=True)
    return shuju

#合并数据
def combineDf(df1,*dfs): 
    for dfi in dfs:
        df1 = df1.append(dfi, ignore_index=True)
    return df1

#输出数据
str_data = '/home/sunmd/stock/shuju.xlsx'
#str_data = r'C:\Users\sun-m\Desktop\stock\shuju.xlsx'

#输入路径
file_path = r'/home/sunmd/stock/'
#file_path = 'C:/Users/sun-m/Desktop/stock/'

#固定的列名
columns_name = ['代码', '名称', '涨幅%', '净流入', '大流入', '大流出', '中流入', '中流出', '统计时间']
#读数据表
def read_data():
    return pd.read_excel(str_data)

#写数据表
def save_data(df):
    df.to_excel(str_data)
    
#导入一天的数据
def save_one_day(file_date, columns_name, num):
    df = read_data()
    df_one = loadExcFac(file_path, file_date, columns_name, [num])
    df = combineDf(df, df_one)
    df[columns_name[3:-1]] = df[columns_name[3:-1]].astype(np.int64)
    df.drop_duplicates(inplace=True)
    save_data(df)
    return df

#输出样式
df = read_data()
def rl_style(s):
    lst = []
    if s['涨幅%'] < 0:
        color = 'green'
    elif s['涨幅%'] > 0:
        color = 'red'
    else:
        color = 'white'
    lst.append('color:%s' % color)
    
    if s['净流入'] < 0:
        color = 'green'
    elif s['净流入'] > 0:
        color = 'red'
    else:
        color = 'white'
    lst.append('color:%s' % color)
    
    lst.append('color:red')
    lst.append('color:green')
    lst.append('color:red')
    lst.append('color:green')
    return lst

#数据样式
#print(df['涨幅%'].astype(np.float))
mystl = df.style.apply(rl_style,axis=1, subset=['涨幅%', '净流入',
                                        '大流入', '大流出',
                                        '中流入', '中流出']).format({'涨幅%':"{:+.2%}"}).\
bar(subset=['涨幅%','净流入'], align='mid', color=['#5fba7d', '#d65f5f'], width=100)

#数值标准化
def col_normalizy(df, *cols):
    temp_str = '_nor'
    for col in cols:
        df[col + temp_str] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())
    return df

#涨幅和净流入图标回执
def zf_jlr(df, name, png_name):
    fig,axis = plt.subplots(1,2, figsize=(16,8))
    df['涨幅%'].plot(kind='bar', ax=axis[0], alpha=0.8, title=name + '涨幅统计', rot=45, fontsize=(15))
    df['净流入'].plot(kind='bar', ax=axis[1], alpha=0.8, title=name + '净流入统计', rot=45, fontsize=(15))
    print(file_path+png_name + "保存路径")
    plt.savefig(file_path+png_name, dpi=400)
    print('保存成功')

#饼图回执
def draw_pie(df, name, png_name):
    fig,axis = plt.subplots(1,1, figsize=(8,8))
    plt.title(name)
    plt.fontsize = 15
    plt.pie(df,
           labels = s.index,
           autopct='%.2f%%',
           pctdistance=0.6,
           labeldistance = 1.2,
           startangle=0,
           radius=1.5,
           frame=False)
    print(file_path+png_name + "保存路径")
    fig.subplots_adjust(right=0.7, top=0.7 )  
    plt.savefig(file_path+png_name,dpi=400)
    print('保存成功')

#异常值
#查询异常值
def detectoutliers2(list):
 
    outlier_indices = []  
    # iterate over features(columns)  
  
        # 1st quartile (25%)  
    Q1 = list.quantile(q=0.25)
    # 3rd quartile (75%)  
    Q3 = list.quantile(0.75)  
    # Interquartile range (IQR)  
    IQR = Q3 - Q1  
    # outlier step  
    outlier_step = 1.5 * IQR  
    # Determine a list of indices of outliers for feature col  
    outlier_list_col = list[(list < Q1 - outlier_step) | (list > Q3 + outlier_step )]  
  
    return outlier_list_col 

#异常值进行统计
def ycz():
    df_grp_name = df.groupby('名称').sum()
    name_list = df_grp_name.index
    #建立空的df
    outliers_list_zf = pd.DataFrame(columns=columns_name)
    #涨幅异常值
    for name in name_list:
        lst = detectoutliers2(df[df['名称'] == name]['涨幅%'].sort_values())
        outliers_list_zf = outliers_list_zf.append(df[df['名称'] == name][df[df['名称'] == name]['涨幅%']\
                                                                       .isin(lst)], ignore_index=False)
    outliers_list_zf.drop_duplicates(inplace=True)
    
    #净流入异常值
    
    #建立空的df
    outliers_list_jlr = pd.DataFrame(columns=columns_name)
    
    #净流入异常值
    for name in name_list:
        lst = detectoutliers2(df[df['名称'] == name]['净流入'].sort_values())
        outliers_list_jlr = outliers_list_jlr.append(df[df['名称'] == name][df[df['名称'] == name]['净流入']\
                                                                    .isin(lst)], ignore_index=False)
    outliers_list_jlr.drop_duplicates(inplace=True)
    
    return [outliers_list_zf, outliers_list_jlr]

# %%
file_date = '2018-07'

to_day = '2018-07-02'

df = save_one_day( file_date, columns_name, 2)

df[df['统计时间']=='2018-07-02'].head()
# Out:
#           代码    名称     涨幅%        净流入         大流入         大流出         中流入  \
# 2241  881142  生物制品 -0.0010  181781270  1802562130  1620397680  1080667110
# 2242  881135  纺织制造 -0.0010   -6658857   244956683   200480520   339455840
# 2243  881102   养殖业 -0.0043  -23236230   507215840   512730120   589607390
# 2244  881150    公交 -0.0079  -47632166    70811124   121150801   100807766
# 2245  881154  园区开发 -0.0131  -48556278     5976963    24639787    32580814
#
#              中流出        统计时间
# 2241  1081050290  2018-07-02
# 2242   390590860  2018-07-02
# 2243   607329340  2018-07-02
# 2244    98100255  2018-07-02
# 2245    62474268  2018-07-02

# %%
df[df['统计时间']==to_day].sort_values('净流入',ascending=False)\
.style.use(mystl.export()).format({'涨幅%':"{:+.2%}"})
# Out:
# <style  type="text/css" >
#     #T_385b0244_7df5_11e8_b491_3052cb810eb9row0_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 87.9%, #5fba7d 87.9%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 94.8%, #d65f5f 94.8%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row1_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 87.9%, #5fba7d 87.9%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row1_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 94.7%, #5fba7d 94.7%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 78.4%, #5fba7d 78.4%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 94.2%, #5fba7d 94.2%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row3_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 68.0%, #5fba7d 68.0%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row3_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.5%, #5fba7d 93.5%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row4_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 53.0%, #5fba7d 53.0%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row4_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.5%, #5fba7d 93.5%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row5_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 86.2%, #5fba7d 86.2%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.4%, #5fba7d 93.4%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.9%, #5fba7d 51.9%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 93.3%, #5fba7d 93.3%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 81.0%, #5fba7d 81.0%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 92.3%, #5fba7d 92.3%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 52.4%, #5fba7d 52.4%, #5fba7d 90.8%, transparent 90.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 92.3%, #5fba7d 92.3%, #5fba7d 94.8%, transparent 94.8%);
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_385b0244_7df5_11e8_b491_3052cb810eb9row8_col5 {
#             col

# %%
#按分类进行统计

df_grp_name = df[df['统计时间']>file_date+'-02'].groupby('名称').sum()
df_grp_name.sort_values(['涨幅%','净流入'], ascending=False)\
.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/style.py in _repr_html_(self)
#     153     def _repr_html_(self):
#     154         """Hooks into Jupyter notebook rich display system."""
# --> 155         return self.render()
#     156
#     157     @Appender(_shared_docs['to_excel'] % dict(
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/style.py in render(self, **kwargs)
#     435         * table_attributes
#     436         """
# --> 437         self._compute()
#     438         # TODO: namespace all the pandas keys
#     439         d = self._translate()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/style.py in _compute(self)
#     503         r = self
#     504         for func, args, kwargs in self._todo:
# --> 505             r = func(self)(*args, **kwargs)
#     506         return r
#     507
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/io/formats/style.py in _apply(self, func, axis, subset, **kwargs)
#     533                                                        res=result.shape,
#     534                                                        expect=expected_shape))
# --> 535             raise ValueError(msg)
#     536         self._update_ctx(result)
#     537         return self
#
# ValueError: Function <function Styler._bar_center_mid at 0x7fed26a9a620> returned the wrong shape.
# Result has shape: (2,)
# Expected shape:   (0, 2)

# %%
#按时间进行统计
df_grp_time = df.groupby('统计时间').sum()
df_grp_time.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})

zf_jlr(df_grp_time[-10:], "按时间进行", "1.png")

#大资金流入饼图
s = df[df['统计时间']==to_day]['大流入']
s.index = df[df['统计时间']==to_day]['名称']

s = s.sort_values(ascending=False)[:10]
draw_pie(s, '今天大资金流入', '2.png')

#大资金流出饼图
s = df[df['统计时间']==to_day]['大流出']
s.index = df[df['统计时间']==to_day]['名称']

s = s.sort_values(ascending=False)[:10]
draw_pie(s, '今天大资金流出', '3.png')

#按分类进行统计
df_grp_name = df[df['统计时间']>'2018-06-29'].groupby('名称').sum()
df_grp_name.sort_values(['涨幅%','净流入'], ascending=False)\
.style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})

#前五净流入
df_grp_name_f = df_grp_name.sort_values(['净流入','涨幅%'], ascending=False)
zf_jlr(df_grp_name_f.iloc[:10], '前五资金流入', '4.png')

#后5净流入
df_grp_name_b = df_grp_name.sort_values(['净流入','涨幅%'])
zf_jlr(df_grp_name_b.iloc[:10], '后五资金流入', '5.png')

#异常值
lst = ycz()

outliers_list_zf = lst[0]
outliers_list_jlr = lst[1]

if not outliers_list_zf[outliers_list_zf['统计时间'] == to_day].empty:
    temp_zf = outliers_list_zf[outliers_list_zf['统计时间'] == to_day]
    num = 0
    for name in temp_zf['名称']:
        df_yczf = df[df['名称']==name]
        df_yczf.index = df_yczf['统计时间']
        zf_jlr(df_yczf[-10:], '异常涨幅板块-' + name, 'ycz_zf' + str(num) +  '.png')
        num = num + 1
        
if not outliers_list_jlr[outliers_list_jlr['统计时间'] == to_day].empty:

    temp_jlr = outliers_list_jlr[outliers_list_jlr['统计时间'] == to_day]
    num = 0
    for name in temp_jlr['名称']:
        df_ycjlr = df[df['名称']==name]
        df_ycjlr.index = df_ycjlr['统计时间']
        zf_jlr(df_ycjlr[-10:], '异常净流入板块-' + name, 'ycz_jlr' + str(num) +  '.png')
        num = num + 1
# Out:
# /home/sunmd/stock/1.png保存路径
# 保存成功
# /home/sunmd/stock/2.png保存路径
# 保存成功
# /home/sunmd/stock/3.png保存路径
# 保存成功
# /home/sunmd/stock/4.png保存路径
# 保存成功
# /home/sunmd/stock/5.png保存路径
# 保存成功
# /home/sunmd/stock/ycz_zf0.png保存路径
# 保存成功
# /home/sunmd/stock/ycz_jlr0.png保存路径
# 保存成功

# %%
#单个板块进行查看
df[df['名称'] == '房地产开发'].style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_839cc440_7df5_11e8_b491_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.1%, #d65f5f 76.1%, #d65f5f 83.3%, transparent 83.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row0_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 66.8%, #5fba7d 66.8%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.1%, #d65f5f 76.1%, #d65f5f 83.3%, transparent 83.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row1_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 66.8%, #5fba7d 66.8%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row2_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 70.8%, #5fba7d 70.8%, #5fba7d 76.1%, transparent 76.1%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row2_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 48.6%, #5fba7d 48.6%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row3_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.1%, #d65f5f 76.1%, #d65f5f 80.2%, transparent 80.2%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.3%, #d65f5f 67.3%, #d65f5f 73.6%, transparent 73.6%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row4_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.1%, #d65f5f 76.1%, #d65f5f 80.2%, transparent 80.2%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 67.3%, #d65f5f 67.3%, #d65f5f 73.6%, transparent 73.6%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row5_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.1%, #d65f5f 76.1%, #d65f5f 82.1%, transparent 82.1%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 49.3%, #5fba7d 49.3%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 73.1%, #5fba7d 73.1%, #5fba7d 76.1%, transparent 76.1%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 20.0%, #5fba7d 20.0%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 64.3%, #5fba7d 64.3%, #5fba7d 76.1%, transparent 76.1%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 31.1%, #5fba7d 31.1%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row8_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 76.1%, #d65f5f 76.1%, #d65f5f 77.4%, transparent 77.4%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.2%, #5fba7d 51.2%, #5fba7d 67.3%, transparent 67.3%);
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_839cc440_7df5_11e8_b491_3052cb810eb9row8_col5 {
#             color: green;

# %%
outliers_list_zf.drop_duplicates().sort_values('统计时间').style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_85cb7644_7df5_11e8_b491_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 53.1%, #d65f5f 53.1%, #d65f5f 69.8%, transparent 69.8%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 47.0%, #d65f5f 47.0%, #d65f5f 67.3%, transparent 67.3%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 53.1%, #d65f5f 53.1%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 47.0%, #d65f5f 47.0%, #d65f5f 52.7%, transparent 52.7%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row2_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 53.1%, #d65f5f 53.1%, #d65f5f 69.8%, transparent 69.8%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row2_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 47.0%, #d65f5f 47.0%, #d65f5f 67.3%, transparent 67.3%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row3_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 30.5%, #5fba7d 30.5%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row3_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 14.3%, #5fba7d 14.3%, #5fba7d 47.0%, transparent 47.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row4_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 25.5%, #5fba7d 25.5%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row4_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 43.2%, #5fba7d 43.2%, #5fba7d 47.0%, transparent 47.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row5_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.2%, #5fba7d 27.2%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row5_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 36.6%, #5fba7d 36.6%, #5fba7d 47.0%, transparent 47.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row6_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 27.5%, #5fba7d 27.5%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row6_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 34.7%, #5fba7d 34.7%, #5fba7d 47.0%, transparent 47.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row7_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 33.6%, #5fba7d 33.6%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row7_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.0%, #5fba7d 45.0%, #5fba7d 47.0%, transparent 47.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row8_col2 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 32.3%, #5fba7d 32.3%, #5fba7d 53.1%, transparent 53.1%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row8_col3 {
#             color: green;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 45.8%, #5fba7d 45.8%, #5fba7d 47.0%, transparent 47.0%);
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_85cb7644_7df5_11e8_b491_3052cb810eb9row8_col5 {
#             color: green;

# %%
outliers_list_jlr.drop_duplicates().sort_values('统计时间').style.use(mystl.export()).format({'涨幅%':'{:+.2%}'})
# Out:
# <style  type="text/css" >
#     #T_5654d810_7a0d_11e8_9484_3052cb810eb9row0_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 52.9%, transparent 52.9%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row0_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 48.6%, transparent 48.6%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row0_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row0_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row0_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row0_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row1_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 52.9%, transparent 52.9%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row1_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 48.6%, transparent 48.6%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row1_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row1_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row1_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row1_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row2_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 67.1%, transparent 67.1%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row2_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 49.7%, transparent 49.7%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row2_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row2_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row2_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row2_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row3_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 70.2%, transparent 70.2%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row3_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 56.1%, transparent 56.1%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row3_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row3_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row3_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row3_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row4_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 100.0%, transparent 100.0%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row4_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 54.6%, transparent 54.6%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row4_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row4_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row4_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row4_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row5_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 68.6%, transparent 68.6%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row5_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 74.2%, transparent 74.2%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row5_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row5_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row5_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row5_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row6_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 66.9%, transparent 66.9%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row6_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 71.7%, transparent 71.7%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row6_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row6_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row6_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row6_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row7_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 68.6%, transparent 68.6%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row7_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 74.2%, transparent 74.2%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row7_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row7_col5 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row7_col6 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row7_col7 {
#             color: green;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row8_col2 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 51.3%, #d65f5f 51.3%, #d65f5f 70.2%, transparent 70.2%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row8_col3 {
#             color: red;
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0%, transparent 46.9%, #d65f5f 46.9%, #d65f5f 56.1%, transparent 56.1%);
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row8_col4 {
#             color: red;
#         }    #T_5654d810_7a0d_11e8_9484_3052cb810eb9row8_col5 {
#             color: green;
#         }    #T_5654d81
